# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r'level.csv')

# %%
df.head()
# Out:
#    Level  Salary
# 0      1   30100
# 1      2   30282
# 2      3   30519
# 3      4   30800
# 4      5   31118

# %%
plt.scatter(df["Level"],df["Salary"])
plt.show()

# %%
df.corr()
# Out:
#           Level   Salary
# Level   1.00000  0.98988
# Salary  0.98988  1.00000

# %%
x  = df[["Level"]]
y = df["Salary"]

# %%
from sklearn.preprocessing import PolynomialFeatures

# %%
pf = PolynomialFeatures(degree = 2)
pf.fit(x)
x = pf.transform(x)

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.2,random_state = 42)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
lr.score(x_test,y_test)
# Out:
# 0.9998066061461571

# %%
prd = lr.predict(x)

# %%
plt.scatter(df["Level"],df["Salary"])
plt.plot(df["Level"],prd,color = "red")
plt.legend(["org","Pred"])
plt.show()

# %%
y_pred = lr.predict(x)

# %%
import warnings as w
w.filterwarnings("ignore")

# New level to predict
new_level = [[205]]
# Transform it just like the training data
new_level_poly = pf.fit_transform(new_level)
# Predict salary
predicted_salary = lr.predict(new_level_poly)
predicted_salary[0]
# Out:
# 326633.01433946134
